# %%
import pandas as pd
import numpy as np
import source.gprof_out_manipulation2 as gpout

data_set = gpout.GprofOutManip('test-files/akiyo.txt')

data_set.read_gprof_out()
data_set.group_by_class()
df = data_set.df_class

df.sort_values(by='percentageTime')
# Out:
#                             class  percentageTime  cumulativeTime  \
# 147               ProfileFeatures            0.00           51.33
# 120  read_x86_extension_flags(std            0.00           51.33
# 70           ParameterSetMap<SPS>            0.00           51.33
# 67           ParameterSetMap<APS>            0.00          153.99
# 66               BinProbModel_Std            0.00           51.33
# ..                            ...             ...             ...
# 110                   CABACWriter            6.12         3377.73
# 43           unsigned long RdCost            7.86          220.09
# 12                       DQIntern            8.51          672.23
# 119                      no_class           10.30         5330.80
# 61                  AlfCovariance           10.79          431.61
#
#      selfSeconds        calls  selfMs/call  totalMs/call
# 147         0.00          3.0         0.00          0.00
# 120         0.00          6.0         0.00          0.00
# 70          0.00          1.0         0.00          0.00
# 67          0.00          4.0         0.00          0.00
# 66          0.00      25772.0         0.00          0.00
# ..           ...          ...          ...           ...
# 110         3.13   66518220.0         0.00          0.00
# 43          4.03   88254342.0         0.00          0.00
# 12          4.37   80049749.0         0.00          0.02
# 119         5.33  162479240.0         0.01          0.01
# 61          5.54   30510746.0         0.00          0.00
#
# [148 rows x 7 columns]
